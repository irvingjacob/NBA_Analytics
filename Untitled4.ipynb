# %%
# %matplotlib inline

import pandas as pd

# %%
from nba_api.stats.static import players

# %%
player_dictionary = players.get_players()

# %%
curry =  [player for player in player_dictionary if player['full_name'] == 'Stephen Curry'][0]

# %%
curry_id = curry['id']

# %%
curry_id
# Out:
# 201939

# %%
from nba_api.stats.endpoints import playergamelog

# %%
from nba_api.stats.library.parameters import SeasonAll

# %%
gamelog_curry = playergamelog.PlayerGameLog(player_id='201939', season = '2016')

# %%
gamelog_curry_df = gamelog_curry.get_data_frames()[0]

# %%
gamelog_curry_df
# Out:
#    SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22016     201939  0021601229  APR 12, 2017  GSW vs. LAL  W   28    6
# 1      22016     201939  0021601211  APR 10, 2017  GSW vs. UTA  L   30    9
# 2      22016     201939  0021601171  APR 05, 2017    GSW @ PHX  W   35   15
# 3      22016     201939  0021601162  APR 04, 2017  GSW vs. MIN  W   30    7
# 4      22016     201939  0021601152  APR 02, 2017  GSW vs. WAS  W   36   15
# ..       ...        ...         ...           ...          ... ..  ...  ...
# 74     22016     201939  0021600069  NOV 03, 2016  GSW vs. OKC  W   30    6
# 75     22016     201939  0021600054  NOV 01, 2016    GSW @ POR  W   29   10
# 76     22016     201939  0021600036  OCT 30, 2016    GSW @ PHX  W   34    9
# 77     22016     201939  0021600025  OCT 28, 2016    GSW @ NOP  W   34    8
# 78     22016     201939  0021600003  OCT 25, 2016  GSW vs. SAS  L   34    9
#
# ...

# %%
gamelog_curry_all = playergamelog.PlayerGameLog(player_id='201939', season = SeasonAll.all)

# %%
gamelog_curry_df_all = gamelog_curry_all.get_data_frames()[0]

# %%
gamelog_curry_df_all
# Out:
#     SEASON_ID  Player_ID     Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0       22019     201939  0021900929  MAR 05, 2020  GSW vs. TOR  L   27    6
# 1       22019     201939  0021900065  OCT 30, 2019  GSW vs. PHX  L   21    3
# 2       22019     201939  0021900047  OCT 28, 2019    GSW @ NOP  W   31    9
# 3       22019     201939  0021900036  OCT 27, 2019    GSW @ OKC  L   30    7
# 4       22019     201939  0021900016  OCT 24, 2019  GSW vs. LAC  L   30    8
# ..        ...        ...         ...           ...          ... ..  ...  ...
# 694     22009     201939  0020900096  NOV 08, 2009    GSW @ SAC  L   31    4
# 695     22009     201939  0020900082  NOV 06, 2009  GSW vs. LAC  L   22    1
# 696     22009     201939  0020900069  NOV 04, 2009  GSW vs. MEM  W   28    3
# 697     22009     201939  0020900030  OCT 30, 2009    GSW @ PHX  L   39    5
# 698     22009     201939  0020900015  OCT 28, 2009  GSW vs. HOU  L   36    7
#
# ...

# %%
from nba_api.stats.static import teams

# %%
team_dict = teams.get_teams()

# %%
gsw = [team for team in team_dict if team['full_name'] == "Golden State Warriors"][0]

# %%
gsw_id = gsw['id']

# %%
gsw_id
# Out:
# 1610612744

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
gsw_game = leaguegamefinder.LeagueGameFinder(team_id_nullable=gsw_id).get_data_frames()[0]

# %%
gsw_game
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        22019  1610612744               GSW  Golden State Warriors
# 1        22019  1610612744               GSW  Golden State Warriors
# 2        22019  1610612744               GSW  Golden State Warriors
# 3        22019  1610612744               GSW  Golden State Warriors
# 4        22019  1610612744               GSW  Golden State Warriors
# ...        ...         ...               ...                    ...
# 3303     21983  1610612744               GOS  Golden State Warriors
# 3304     21983  1610612744               GOS  Golden State Warriors
# 3305     21983  1610612744               GOS  Golden State Warriors
# 3306     21983  1610612744               GOS  Golden State Warriors
# 3307     21983  1610612744               GOS  Golden State Warriors
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0     0021900967  2020-03-10  GSW vs. LAC  L  239  107  ...   0.815   4.0
# ...

# %%
gsw_game.to_csv("gsw_game.csv", index = False)

# %%
import seaborn as sns

# %%
sns.set()

# %%
gamelog_curry_df_all.to_csv("curryAllGames.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-28-c257ce8024a9> in <module>
# ----> 1 gamelog_curry_df_all.to_csv("curryAllGames.csv")
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# ...

# %%
pd.read_csv("curryAllGames.csv")
# Out:
#      Unnamed: 0  SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  \
# 0             0      22019     201939  21900929  MAR 05, 2020  GSW vs. TOR  L
# 1             1      22019     201939  21900065  OCT 30, 2019  GSW vs. PHX  L
# 2             2      22019     201939  21900047  OCT 28, 2019    GSW @ NOP  W
# 3             3      22019     201939  21900036  OCT 27, 2019    GSW @ OKC  L
# 4             4      22019     201939  21900016  OCT 24, 2019  GSW vs. LAC  L
# ..          ...        ...        ...       ...           ...          ... ..
# 694         694      22009     201939  20900096  NOV 08, 2009    GSW @ SAC  L
# 695         695      22009     201939  20900082  NOV 06, 2009  GSW vs. LAC  L
# 696         696      22009     201939  20900069  NOV 04, 2009  GSW vs. MEM  W
# 697         697      22009     201939  20900030  OCT 30, 2009    GSW @ PHX  L
# 698         698      22009     201939  20900015  OCT 28, 2009  GSW vs. HOU  L
#
# ...

# %%
import pandas as pd
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = gamelog_curry_df_all

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = 'curryAllGames.csv'

# %%
df = pd.read_csv(data, index_col=0)

# %%
df.head()
# Out:
#    SEASON_ID  Player_ID   Game_ID     GAME_DATE      MATCHUP WL  MIN  FGM  \
# 0      22019     201939  21900929  MAR 05, 2020  GSW vs. TOR  L   27    6
# 1      22019     201939  21900065  OCT 30, 2019  GSW vs. PHX  L   21    3
# 2      22019     201939  21900047  OCT 28, 2019    GSW @ NOP  W   31    9
# 3      22019     201939  21900036  OCT 27, 2019    GSW @ OKC  L   30    7
# 4      22019     201939  21900016  OCT 24, 2019  GSW vs. LAC  L   30    8
#
#    FGA  FG_PCT  ...  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0   16   0.375  ...     6    6    7    0    0    1   1   23         -13
# 1   11   0.273  ...     5    5    6    1    2    4   2    9         -15
# 2   17   0.529  ...     2    3   11    3    0    1   5   26          32
# 3   18   0.389  ...     6    8    5    0    0    2   0   23         -30
# 4   20   0.400  ...     3    4    4    1    0    8   3   23         -19
#
#    VIDEO_AVAILABLE
# 0                1
# 1                2
# 2                1
# ...

# %%
sns.scatterplot(x='FG3A', y='FG3M', data = df)

# %%
sns.scatterplot(x='FG3A', y='FG3M', size='PTS', data = df)

# %%
sns.scatterplot(x='FG3A', y='FG3M', size='PTS', hue='WL', data = df, s=10)
fig = plt.gcf()
fig.set_size_inches(12,12)

# %%
fig_dims = (12,12)

# %%
fig, ax = plt.subplots(figsize=fig_dims)

# %%
sns.scatterplot(x='FG3A', y='FG3M', size='PTS', hue='WL', ax=ax, data = df)

# %%
from matplotlib import pyplot

# %%
fig, ax = pyplot.subplots(figsize=fig_dims)

# %%
sns.scatterplot(x='FG3A', y='FG3M', size='PTS', hue='WL', ax=ax, data = df)

# %%
sns.scatterplot(x='FG3A', y='PLUS_MINUS', size='PTS', hue='WL', ax=ax, data = df)

# %%
plt.savefig('curryfg3avsplusminus.png')

# %%
import matplotlib.pyplot as plt

# %%
plt.savefig('curryfg3avsplusminus.png')

# %%
sns.regplot(x='PLUS_MINUS', y='TOV', data = df)
fig = plt.gcf()
fig.set_size_inches(23,13)

# %%
plt.show()

# %%
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-a552cd24eec4> in <module>
# ----> 1 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.show(sns)
